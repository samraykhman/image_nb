# %%
import re
from playwright.sync_api import Page, expect
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting requests
#   Downloading requests-2.31.0-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.6/62.6 KB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting idna<4,>=2.5
#   Downloading idna-3.7-py3-none-any.whl (66 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 KB 6.9 MB/s eta 0:00:00
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.2.1-py3-none-any.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.1/121.1 KB 10.3 MB/s eta 0:00:00
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (142 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.1/142.1 KB 17.1 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2024.2.2-py3-none-any.whl (163 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 163.8/163.8 KB 20.1 MB/s eta 0:00:00
# Installing collected packages: urllib3, idna, charset-normalizer, certifi, requests
# Successfully installed certifi-2024.2.2 charset-normalizer-3.3.2 idna-3.7 requests-2.31.0 urllib3-2.2.1

# %%
pip install pytest-playwright
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting pytest-playwright
#   Downloading pytest_playwright-0.4.4-py3-none-any.whl (10 kB)
# Collecting pytest-base-url<3.0.0,>=1.0.0
#   Downloading pytest_base_url-2.1.0-py3-none-any.whl (5.3 kB)
# Collecting python-slugify<9.0.0,>=6.0.0
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Collecting pytest<9.0.0,>=6.2.4
#   Downloading pytest-8.1.1-py3-none-any.whl (337 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.4/337.4 KB 3.4 MB/s eta 0:00:00a 0:00:01
# Collecting playwright>=1.18
#   Downloading playwright-1.43.0-py3-none-manylinux1_x86_64.whl (37.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.3/37.3 MB 30.9 MB/s eta 0:00:0000:0100:01
# Collecting pyee==11.1.0
#   Downloading pyee-11.1.0-py3-none-any.whl (15 kB)
# Collecting greenlet==3.0.3
#   Downloading greenlet-3.0.3-cp310-cp310-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (616 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 616.0/616.0 KB 74.8 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pyee==11.1.0->playwright>=1.18->pytest-playwright) (4.11.0)
# Collecting iniconfig
#   Downloading iniconfig-2.0.0-py3-none-any.whl (5.9 kB)
# Collecting tomli>=1
#   Downloading tomli-2.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: packaging in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pytest<9.0.0,>=6.2.4->pytest-playwright) (24.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc8 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pytest<9.0.0,>=6.2.4->pytest-playwright) (1.2.0)
# Collecting pluggy<2.0,>=1.4
#   Downloading pluggy-1.4.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: requests>=2.9 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2.31.0)
# Collecting text-unidecode>=1.3
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 KB 22.7 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (3.3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2024.2.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (2.2.1)
# Requirement already satisfied: idna<4,>=2.5 in /workspace/.pyenv_mirror/user/current/lib/python3.10/site-packages (from requests>=2.9->pytest-base-url<3.0.0,>=1.0.0->pytest-playwright) (3.7)
# Installing collected packages: text-unidecode, tomli, python-slugify, pyee, pluggy, iniconfig, greenlet, pytest, playwright, pytest-base-url, pytest-playwright
# Successfully installed greenlet-3.0.3 iniconfig-2.0.0 playwright-1.43.0 pluggy-1.4.0 pyee-11.1.0 pytest-8.1.1 pytest-base-url-2.1.0 pytest-playwright-0.4.4 python-slugify-8.0.4 text-unidecode-1.3 tomli-2.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# !playwright install-deps
# Out:
# Installing dependencies...
# Switching to root user to install dependencies...
# Get:2 https://download.docker.com/linux/ubuntu jammy InRelease [48.8 kB]
# Get:1 https://apt.llvm.org/jammy llvm-toolchain-jammy-17 InRelease [6,833 B]
# Get:3 https://download.docker.com/linux/ubuntu jammy/stable amd64 Packages [35.2 kB]
# Get:4 https://apt.llvm.org/jammy llvm-toolchain-jammy-17/main amd64 Packages [12.4 kB]
# Get:6 http://security.ubuntu.com/ubuntu jammy-security InRelease [110 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [119 kB]
# Get:5 https://packagecloud.io/github/git-lfs/ubuntu jammy InRelease [28.0 kB]
# Get:10 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [44.7 kB]
# Get:9 https://packagecloud.io/github/git-lfs/ubuntu jammy/main amd64 Packages [1,842 B]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [109 kB]
# Hit:12 https://ppa.launchpadcontent.net/git-core/ppa/ubuntu jammy InRelease
# Get:13 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1,081 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy-updates/restricted amd64 Packages [2,174 kB]
# Get:15 https://ppa.launchpadcontent.net/ondrej/apache2/ubuntu jammy InRelease [23.8 kB]
# Get:16 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [2,124 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 Packages [1,974 kB]
# Get:18 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [1,691 kB]
# Get:19 https://ppa.launchpadcontent.net/ondrej/nginx-mainline/ubuntu jammy InRelease [23.8 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 Packages [1,357 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy-updates/multiverse amd64 Packages [61.3 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy-backports/main amd64 Packages [80.9 kB]
# Get:23 http://archive.ubuntu.com/ubuntu jammy-backports/universe amd64 Packages [33.3 kB]
# Get:24 https://ppa.launchpadcontent.net/ondrej/php/ubuntu jammy InRelease [23.9 kB]
# Get:25 https://ppa.launchpadcontent.net/ondrej/apache2/ubuntu jammy/main amd64 Packages [5,151 B]
# Get:26 https://ppa.launchpadcontent.net/ondrej/nginx-mainline/ubuntu jammy/main amd64 Packages [9,958 B]
# Get:27 https://ppa.launchpadcontent.net/ondrej/php/ubuntu jammy/main amd64 Packages [208 kB]
# Fetched 11.4 MB in 2s (5,228 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# libasound2 is already the newest version (1.2.6.1-1ubuntu1).
# libasound2 set to manually installed.
# libcairo-gobject2 is already the newest version (1.16.0-5ubuntu2).
# libcairo-gobject2 set to manually installed.
# libcairo2 is already the newest version (1.16.0-5ubuntu2).
# libcairo2 set to manually installed.
# libevent-2.1-7 is already the newest version (2.1.12-stable-1build3).
# libevent-2.1-7 set to manually installed.
# libfontconfig1 is already the newest version (2.13.1-4.2ubuntu5).
# libfontconfig1 set to manually installed.
# libicu70 is already the newest version (70.1-2).
# libicu70 set to manually installed.
# libjpeg-turbo8 is already the newest version (2.1.2-0ubuntu1).
# libjpeg-turbo8 set to manually installed.
# liblcms2-2 is already the newest version (2.12~rc1-2build2).
# liblcms2-2 set to manually installed.
# libopenjp2-7 is already the newest version (2.4.0-6).
# libopenjp2-7 set to manually installed.
# libpng16-16 is already the newest version (1.6.37-3build5).
# libpng16-16 set to manually installed.
# libxcb-shm0 is already the newest version (1.14-3ubuntu3).
# libxcb-shm0 set to manually installed.
# libxcb1 is already the newest version (1.14-3ubuntu3).
# libxcb1 set to manually installed.
# libxext6 is already the newest version (2:1.3.4-1build1).
# libxext6 set to manually installed.
# libxrender1 is already the newest version (1:0.9.10-1build4).
# libxrender1 set to manually installed.
# libatomic1 is already the newest version (12.3.0-1ubuntu1~22.04).
# libatomic1 set to manually installed.
# libdbus-1-3 is already the newest version (1.12.20-2ubuntu4.1).
# libdbus-1-3 set to manually installed.
# libfreetype6 is already the newest version (2.11.1+dfsg-1ubuntu0.2).
# libfreetype6 set to manually installed.
# libgdk-pixbuf-2.0-0 is already the newest version (2.42.8+dfsg-1ubuntu0.2).
# libgdk-pixbuf-2.0-0 set to manually installed.
# libglib2.0-0 is already the newest version (2.72.4-0ubuntu2.2).
# libglib2.0-0 set to manually installed.
# libgstreamer1.0-0 is already the newest version (1.20.3-0ubuntu1).
# libgstreamer1.0-0 set to manually installed.
# libharfbuzz0b is already the newest version (2.7.4-1ubuntu3.1).
# libharfbuzz0b set to manually installed.
# libpango-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpango-1.0-0 set to manually installed.
# libpangocairo-1.0-0 is already the newest version (1.50.6+ds-2ubuntu1).
# libpangocairo-1.0-0 set to manually installed.
# libwebpdemux2 is already the newest version (1.2.2-2ubuntu0.22.04.2).
# libwebpdemux2 set to manually installed.
# libx11-6 is already the newest version (2:1.7.5-1ubuntu0.3).
# libx11-6 set to manually installed.
# libxslt1.1 is already the newest version (1.1.34-4ubuntu0.22.04.1).
# libxslt1.1 set to manually installed.
# The following additional packages will be installed:
#   adwaita-icon-theme dbus-user-session dconf-gsettings-backend dconf-service
#   dictionaries-common glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gtk-update-icon-cache
#   humanity-icon-theme hunspell-en-us libaa1 libaspell15 libass9 libasyncns0
#   libatk1.0-data libavahi-client3 libavahi-common-data libavahi-common3
#   libavc1394-0 libavcodec58 libavdevice58 libavfilter7 libavformat58
#   libavutil56 libblas3 libbluray2 libbs2b0 libcaca0 libcdio-cdda2
#   libcdio-paranoia2 libcdio19 libcdparanoia0 libchromaprint1 libcodec2-1.0
#   libcolord2 libdc1394-25 libdca0 libdconf1 libdecor-0-0 libdrm-amdgpu1
#   libdrm-common libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdv4 libdvdnav4
#   libdvdread8 libegl-mesa0 libfaad2 libflac8 libflite1 libfluidsynth3
#   libfontenc1 libfreeaptx0 libgfortran5 libgl1 libgl1-mesa-dri libglapi-mesa
#   libglvnd0 libglx-mesa0 libgme0 libgsm1 libgssdp-1.2-0
#   libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-good1.0-0 libgtk-3-common
#   libgupnp-1.2-1 libgupnp-igd-1.0-4 libhunspell-1.7-0 libiec61883-0
#   libinstpatch-1.0-2 libjack-jackd2-0 libjson-glib-1.0-0
#   libjson-glib-1.0-common libkate1 liblapack3 libldacbt-enc2 liblilv-0-0
#   libllvm15 libltc11 libmfx1 libmjpegutils-2.1-0 libmodplug1 libmp3lame0
#   libmpcdec6 libmpeg2encpp-2.1-0 libmpg123-0 libmplex2-2.1-0 libmysofa1
#   libnice10 libnorm1 libogg0 libopenal-data libopenal1 libopenh264-6
#   libopenmpt0 libopenni2-0 liborc-0.4-0 libpciaccess0 libpgm-5.3-0
#   libpocketsphinx3 libpostproc55 libpulse0 libqrencode4 librabbitmq4
#   libraw1394-11 librubberband2 libsamplerate0 libsbc1 libsdl2-2.0-0
#   libsecret-common libsensors-config libsensors5 libserd-0-0 libshine3
#   libshout3 libslang2 libsnappy1v5 libsndfile1 libsndio7.0 libsord-0-0
#   libsoundtouch1 libsoup-3.0-common libsoup2.4-1 libsoup2.4-common libsoxr0
#   libspandsp2 libspeex1 libsphinxbase3 libsratom-0-0 libsrt1.4-gnutls
#   libsrtp2-1 libssh-gcrypt-4 libswresample3 libswscale5 libtag1v5
#   libtag1v5-vanilla libtext-iconv-perl libtheora0 libtwolame0 libudfread0
#   libusb-1.0-0 libv4l-0 libv4lconvert0 libva-drm2 libva-x11-2 libva2 libvdpau1
#   libvidstab1.1 libvisual-0.4-0 libvo-aacenc0 libvo-amrwbenc0 libvorbis0a
#   libvorbisenc2 libvorbisfile3 libvpx7 libwavpack1 libwayland-cursor0
#   libwebrtc-audio-processing1 libwildmidi2 libxaw7 libxcb-dri2-0 libxcb-dri3-0
#   libxcb-glx0 libxcb-present0 libxcb-randr0 libxcb-shape0 libxcb-sync1
#   libxcb-xfixes0 libxfont2 libxinerama1 libxkbfile1 libxml2-dev libxmu6
#   libxmuu1 libxpm4 libxshmfence1 libxss1 libxv1 libxvidcore4 libxxf86vm1
#   libzbar0 libzimg2 libzmq5 libzvbi-common libzvbi0 libzxingcore1
#   ocl-icd-libopencl1 session-migration timgm6mb-soundfont ubuntu-mono
#   x11-xkb-utils xauth xfonts-encodings xfonts-utils xkb-data xserver-common
# Suggested packages:
#   ispell | aspell | hunspell wordlist ffmpeg-doc frei0r-plugins gvfs hunspell
#   openoffice.org-hunspell | openoffice.org-core aspell libcuda1 libnvcuvid1
#   libnvidia-encode1 libbluray-bdj colord cups-common libdv-bin oss-compat
#   libdvdcss2 libenchant-2-voikko libvisual-0.4-plugins jackd2 gnome-shell
#   | notification-daemon libportaudio2 opus-tools pciutils pulseaudio
#   libraw1394-doc xdg-utils lm-sensors serdi sndiod sordi speex
#   libwildmidi-config opencl-icd fluid-soundfont-gm
# Recommended packages:
#   fonts-ipafont-mincho fonts-tlwg-loma gstreamer1.0-x aspell-en
#   | aspell-dictionary | aspell6a-dictionary at-spi2-core libaacs0
#   libdecor-0-plugin-1-cairo | libdecor-0-plugin-1 enchant-2 libgl1-amber-dri
#   gstreamer1.0-gl libgtk-3-bin pocketsphinx-en-us va-driver-all | va-driver
#   vdpau-driver-all | vdpau-driver xfonts-base
# The following NEW packages will be installed:
#   adwaita-icon-theme dbus-user-session dconf-gsettings-backend dconf-service
#   dictionaries-common ffmpeg fonts-freefont-ttf fonts-ipafont-gothic
#   fonts-liberation fonts-noto-color-emoji fonts-tlwg-loma-otf fonts-unifont
#   fonts-wqy-zenhei glib-networking glib-networking-common
#   glib-networking-services gsettings-desktop-schemas gstreamer1.0-libav
#   gstreamer1.0-plugins-bad gstreamer1.0-plugins-base gstreamer1.0-plugins-good
#   gtk-update-icon-cache humanity-icon-theme hunspell-en-us libaa1 libaspell15
#   libass9 libasyncns0 libatk-bridge2.0-0 libatk1.0-0 libatk1.0-data
#   libatspi2.0-0 libavahi-client3 libavahi-common-data libavahi-common3
#   libavc1394-0 libavcodec58 libavdevice58 libavfilter7 libavformat58
#   libavutil56 libblas3 libbluray2 libbs2b0 libcaca0 libcdio-cdda2
#   libcdio-paranoia2 libcdio19 libcdparanoia0 libchromaprint1 libcodec2-1.0
#   libcolord2 libcups2 libdbus-glib-1-2 libdc1394-25 libdca0 libdconf1
#   libdecor-0-0 libdrm-amdgpu1 libdrm-common libdrm-intel1 libdrm-nouveau2
#   libdrm-radeon1 libdrm2 libdv4 libdvdnav4 libdvdread8 libegl-mesa0 libegl1
#   libenchant-2-2 libepoxy0 libevdev2 libfaad2 libffi7 libflac8 libflite1
#   libfluidsynth3 libfontenc1 libfreeaptx0 libgbm1 libgfortran5 libgl1
#   libgl1-mesa-dri libglapi-mesa libgles2 libglvnd0 libglx-mesa0 libglx0
#   libgme0 libgsm1 libgssdp-1.2-0 libgstreamer-gl1.0-0
#   libgstreamer-plugins-bad1.0-0 libgstreamer-plugins-base1.0-0
#   libgstreamer-plugins-good1.0-0 libgtk-3-0 libgtk-3-common libgudev-1.0-0
#   libgupnp-1.2-1 libgupnp-igd-1.0-4 libharfbuzz-icu0 libhunspell-1.7-0
#   libhyphen0 libiec61883-0 libinstpatch-1.0-2 libjack-jackd2-0
#   libjson-glib-1.0-0 libjson-glib-1.0-common libkate1 liblapack3
#   libldacbt-enc2 liblilv-0-0 libllvm15 libltc11 libmanette-0.2-0 libmfx1
#   libmjpegutils-2.1-0 libmodplug1 libmp3lame0 libmpcdec6 libmpeg2encpp-2.1-0
#   libmpg123-0 libmplex2-2.1-0 libmysofa1 libnice10 libnorm1 libnotify4
#   libnspr4 libnss3 libogg0 libopenal-data libopenal1 libopengl0 libopenh264-6
#   libopenmpt0 libopenni2-0 libopus0 liborc-0.4-0 libpciaccess0 libpgm-5.3-0
#   libpocketsphinx3 libpostproc55 libproxy1v5 libpulse0 libqrencode4
#   librabbitmq4 libraw1394-11 librubberband2 libsamplerate0 libsbc1
#   libsdl2-2.0-0 libsecret-1-0 libsecret-common libsensors-config libsensors5
#   libserd-0-0 libshine3 libshout3 libslang2 libsnappy1v5 libsndfile1
#   libsndio7.0 libsord-0-0 libsoundtouch1 libsoup-3.0-0 libsoup-3.0-common
#   libsoup2.4-1 libsoup2.4-common libsoxr0 libspandsp2 libspeex1 libsphinxbase3
#   libsratom-0-0 libsrt1.4-gnutls libsrtp2-1 libssh-gcrypt-4 libswresample3
#   libswscale5 libtag1v5 libtag1v5-vanilla libtext-iconv-perl libtheora0
#   libtwolame0 libudfread0 libusb-1.0-0 libv4l-0 libv4lconvert0 libva-drm2
#   libva-x11-2 libva2 libvdpau1 libvidstab1.1 libvisual-0.4-0 libvo-aacenc0
#   libvo-amrwbenc0 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx7 libwavpack1
#   libwayland-client0 libwayland-cursor0 libwayland-egl1 libwayland-server0
#   libwebrtc-audio-processing1 libwildmidi2 libwoff1 libx11-xcb1 libx264-163
#   libxaw7 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0 libxcb-present0
#   libxcb-randr0 libxcb-shape0 libxcb-sync1 libxcb-xfixes0 libxcomposite1
#   libxcursor1 libxdamage1 libxfixes3 libxfont2 libxi6 libxinerama1
#   libxkbcommon0 libxkbfile1 libxmu6 libxmuu1 libxpm4 libxrandr2 libxshmfence1
#   libxss1 libxtst6 libxv1 libxvidcore4 libxxf86vm1 libzbar0 libzimg2 libzmq5
#   libzvbi-common libzvbi0 libzxingcore1 ocl-icd-libopencl1 session-migration
#   timgm6mb-soundfont ubuntu-mono x11-xkb-utils xauth xfonts-cyrillic
#   xfonts-encodings xfonts-scalable xfonts-utils xkb-data xserver-common xvfb
# The following packages will be upgraded:
#   libxml2 libxml2-dev
# 2 upgraded, 256 newly installed, 0 to remove and 46 not upgraded.
# Need to get 151 MB of archives.
# After this operation, 480 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-ipafont-gothic all 00303-21ubuntu1 [3,513 kB]
# Get:2 https://ppa.launchpadcontent.net/ondrej/php/ubuntu jammy/main amd64 libxml2-dev amd64 2.9.14+dfsg-0.1+ubuntu22.04.1+deb.sury.org+1 [882 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/main amd64 libslang2 amd64 2.3.2-5build4 [468 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtext-iconv-perl amd64 1.7-7build3 [14.3 kB]
# Get:5 http://archive.ubuntu.com/ubuntu jammy/main amd64 xkb-data all 2.33-1 [394 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-common all 2.4.113-2~ubuntu0.22.04.1 [5,450 B]
# Get:7 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm2 amd64 2.4.113-2~ubuntu0.22.04.1 [38.1 kB]
# Get:8 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libusb-1.0-0 amd64 2:1.0.25-1ubuntu2 [52.7 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmuu1 amd64 2:1.1.3-3 [10.2 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/main amd64 xauth amd64 1:1.1-1build2 [27.5 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gtk-update-icon-cache amd64 3.24.33-1ubuntu2 [31.4 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 humanity-icon-theme all 0.6.16 [1,282 kB]
# Get:13 http://archive.ubuntu.com/ubuntu jammy/main amd64 ubuntu-mono all 20.10-0ubuntu2 [153 kB]
# Get:14 http://archive.ubuntu.com/ubuntu jammy/main amd64 adwaita-icon-theme all 41.0-1ubuntu1 [3,444 kB]
# Get:15 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 dbus-user-session amd64 1.12.20-2ubuntu4.1 [9,442 B]
# Get:16 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdconf1 amd64 0.40.0-3 [40.5 kB]
# Get:17 http://archive.ubuntu.com/ubuntu jammy/main amd64 dconf-service amd64 0.40.0-3 [28.5 kB]
# Get:18 http://archive.ubuntu.com/ubuntu jammy/main amd64 dconf-gsettings-backend amd64 0.40.0-3 [22.8 kB]
# Get:19 http://archive.ubuntu.com/ubuntu jammy/main amd64 dictionaries-common all 1.28.14 [185 kB]
# Get:20 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva2 amd64 2.14.0-1 [65.0 kB]
# Get:21 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmfx1 amd64 22.3.0-1 [3,105 kB]
# Get:22 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva-drm2 amd64 2.14.0-1 [7,502 B]
# Get:23 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfixes3 amd64 1:6.0.0-1 [11.7 kB]
# Get:24 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libva-x11-2 amd64 2.14.0-1 [12.6 kB]
# Get:25 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvdpau1 amd64 1.4-3build2 [27.0 kB]
# Get:26 http://archive.ubuntu.com/ubuntu jammy/universe amd64 ocl-icd-libopencl1 amd64 2.2.14-3 [39.1 kB]
# Get:27 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavutil56 amd64 7:4.4.2-0ubuntu0.22.04.1 [290 kB]
# Get:28 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libcodec2-1.0 amd64 1.0.1-3 [8,435 kB]
# Get:29 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgsm1 amd64 1.0.19-1 [27.7 kB]
# Get:30 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmp3lame0 amd64 3.100-3build2 [141 kB]
# Get:31 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopus0 amd64 1.3.1-0.1build2 [203 kB]
# Get:32 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libshine3 amd64 3.1.1-2 [23.2 kB]
# Get:33 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsnappy1v5 amd64 1.1.8-1build3 [17.5 kB]
# Get:34 http://archive.ubuntu.com/ubuntu jammy/main amd64 libspeex1 amd64 1.2~rc1.2-1.1ubuntu3 [57.9 kB]
# Get:35 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsoxr0 amd64 0.1.3-4build2 [79.8 kB]
# Get:36 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswresample3 amd64 7:4.4.2-0ubuntu0.22.04.1 [62.2 kB]
# Get:37 http://archive.ubuntu.com/ubuntu jammy/main amd64 libogg0 amd64 1.3.5-0ubuntu3 [22.9 kB]
# Get:38 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtheora0 amd64 1.1.1+dfsg.1-15ubuntu4 [209 kB]
# Get:39 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtwolame0 amd64 0.4.0-2build2 [52.5 kB]
# Get:40 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbis0a amd64 1.3.7-1build2 [99.2 kB]
# Get:41 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisenc2 amd64 1.3.7-1build2 [82.6 kB]
# Get:42 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libvpx7 amd64 1.11.0-2ubuntu2.2 [1,078 kB]
# Get:43 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libx264-163 amd64 2:0.163.3060+git5db6aa6-2build1 [591 kB]
# Get:44 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libxvidcore4 amd64 2:1.3.7-1 [201 kB]
# Get:45 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi-common all 0.2.35-19 [35.5 kB]
# Get:46 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzvbi0 amd64 0.2.35-19 [262 kB]
# Get:47 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavcodec58 amd64 7:4.4.2-0ubuntu0.22.04.1 [5,567 kB]
# Get:48 http://archive.ubuntu.com/ubuntu jammy/main amd64 libraw1394-11 amd64 2.1.2-2build2 [27.0 kB]
# Get:49 http://archive.ubuntu.com/ubuntu jammy/main amd64 libavc1394-0 amd64 0.5.4-5build2 [17.0 kB]
# Get:50 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libass9 amd64 1:0.15.2-1 [97.5 kB]
# Get:51 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libudfread0 amd64 1.1.2-1 [16.2 kB]
# Get:52 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbluray2 amd64 1:1.3.1-1 [159 kB]
# Get:53 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libchromaprint1 amd64 1.5.1-2 [28.4 kB]
# Get:54 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgme0 amd64 0.6.3-2 [127 kB]
# Get:55 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmpg123-0 amd64 1.29.3-1build1 [172 kB]
# Get:56 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvorbisfile3 amd64 1.3.7-1build2 [17.1 kB]
# Get:57 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenmpt0 amd64 0.6.1-1 [592 kB]
# Get:58 http://archive.ubuntu.com/ubuntu jammy/main amd64 librabbitmq4 amd64 0.10.0-1ubuntu2 [39.3 kB]
# Get:59 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrt1.4-gnutls amd64 1.4.4-4 [309 kB]
# Get:60 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libssh-gcrypt-4 amd64 0.9.6-2ubuntu0.22.04.3 [223 kB]
# Get:61 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnorm1 amd64 1.5.9+dfsg-2 [221 kB]
# Get:62 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpgm-5.3-0 amd64 5.3.128~dfsg-2 [161 kB]
# Get:63 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzmq5 amd64 4.3.4-2 [256 kB]
# Get:64 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavformat58 amd64 7:4.4.2-0ubuntu0.22.04.1 [1,103 kB]
# Get:65 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libbs2b0 amd64 3.1.0+dfsg-2.2build1 [10.2 kB]
# Get:66 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libflite1 amd64 2.2-3 [13.7 MB]
# Get:67 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libserd-0-0 amd64 0.30.10-2 [40.8 kB]
# Get:68 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsord-0-0 amd64 0.16.8-2 [21.2 kB]
# Get:69 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsratom-0-0 amd64 0.6.8-1 [17.0 kB]
# Get:70 http://archive.ubuntu.com/ubuntu jammy/universe amd64 liblilv-0-0 amd64 0.24.12-2 [42.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmysofa1 amd64 1.2.1~dfsg0-1 [1,157 kB]
# Get:72 http://archive.ubuntu.com/ubuntu jammy/main amd64 libblas3 amd64 3.10.0-2ubuntu1 [228 kB]
# Get:73 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgfortran5 amd64 12.3.0-1ubuntu1~22.04 [879 kB]
# Get:74 http://archive.ubuntu.com/ubuntu jammy/main amd64 liblapack3 amd64 3.10.0-2ubuntu1 [2,504 kB]
# Get:75 http://archive.ubuntu.com/ubuntu jammy/main amd64 libasyncns0 amd64 0.8-6build2 [12.8 kB]
# Get:76 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libflac8 amd64 1.3.3-2ubuntu0.2 [111 kB]
# Get:77 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsndfile1 amd64 1.0.31-2ubuntu0.1 [197 kB]
# Get:78 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libx11-xcb1 amd64 2:1.7.5-1ubuntu0.3 [7,802 B]
# Get:79 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libpulse0 amd64 1:15.99.1+dfsg1-1ubuntu2.2 [298 kB]
# Get:80 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsphinxbase3 amd64 0.8+5prealpha+1-13build1 [126 kB]
# Get:81 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libpocketsphinx3 amd64 0.8.0+real5prealpha+1-14ubuntu1 [132 kB]
# Get:82 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libpostproc55 amd64 7:4.4.2-0ubuntu0.22.04.1 [60.1 kB]
# Get:83 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsamplerate0 amd64 0.2.2-1build1 [1,359 kB]
# Get:84 http://archive.ubuntu.com/ubuntu jammy/universe amd64 librubberband2 amd64 2.0.0-2 [90.0 kB]
# Get:85 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libswscale5 amd64 7:4.4.2-0ubuntu0.22.04.1 [180 kB]
# Get:86 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvidstab1.1 amd64 1.1.0-2 [35.0 kB]
# Get:87 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzimg2 amd64 3.0.3+ds1-1 [241 kB]
# Get:88 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavfilter7 amd64 7:4.4.2-0ubuntu0.22.04.1 [1,496 kB]
# Get:89 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcaca0 amd64 0.99.beta19-2.2ubuntu4 [224 kB]
# Get:90 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdio19 amd64 2.1.0-3build1 [63.3 kB]
# Get:91 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-cdda2 amd64 10.2+2.0.0-1build3 [16.7 kB]
# Get:92 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdio-paranoia2 amd64 10.2+2.0.0-1build3 [15.9 kB]
# Get:93 https://ppa.launchpadcontent.net/ondrej/php/ubuntu jammy/main amd64 libxml2 amd64 2.9.14+dfsg-0.1+ubuntu22.04.1+deb.sury.org+1 [839 kB]
# Get:94 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdc1394-25 amd64 2.2.6-4 [88.8 kB]
# Get:95 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglvnd0 amd64 1.4.0-1 [73.6 kB]
# Get:96 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglapi-mesa amd64 23.2.1-1ubuntu3.1~22.04.2 [37.1 kB]
# Get:97 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-dri2-0 amd64 1.14-3ubuntu3 [7,206 B]
# Get:98 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-dri3-0 amd64 1.14-3ubuntu3 [6,968 B]
# Get:99 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-glx0 amd64 1.14-3ubuntu3 [25.9 kB]
# Get:100 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-present0 amd64 1.14-3ubuntu3 [5,734 B]
# Get:101 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-randr0 amd64 1.14-3ubuntu3 [18.3 kB]
# Get:102 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-sync1 amd64 1.14-3ubuntu3 [9,416 B]
# Get:103 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-xfixes0 amd64 1.14-3ubuntu3 [9,996 B]
# Get:104 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxshmfence1 amd64 1.3-1build4 [5,394 B]
# Get:105 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxxf86vm1 amd64 1:1.1.4-1build3 [10.4 kB]
# Get:106 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-amdgpu1 amd64 2.4.113-2~ubuntu0.22.04.1 [19.9 kB]
# Get:107 http://archive.ubuntu.com/ubuntu jammy/main amd64 libpciaccess0 amd64 0.16-3 [19.1 kB]
# Get:108 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-intel1 amd64 2.4.113-2~ubuntu0.22.04.1 [66.7 kB]
# Get:109 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-nouveau2 amd64 2.4.113-2~ubuntu0.22.04.1 [17.5 kB]
# Get:110 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libdrm-radeon1 amd64 2.4.113-2~ubuntu0.22.04.1 [21.6 kB]
# Get:111 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libllvm15 amd64 1:15.0.7-0ubuntu0.22.04.3 [25.4 MB]
# Get:112 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsensors-config all 1:3.6.0-7ubuntu1 [5,274 B]
# Get:113 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsensors5 amd64 1:3.6.0-7ubuntu1 [26.3 kB]
# Get:114 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgl1-mesa-dri amd64 23.2.1-1ubuntu3.1~22.04.2 [8,860 kB]
# Get:115 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libglx-mesa0 amd64 23.2.1-1ubuntu3.1~22.04.2 [158 kB]
# Get:116 http://archive.ubuntu.com/ubuntu jammy/main amd64 libglx0 amd64 1.4.0-1 [41.0 kB]
# Get:117 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgl1 amd64 1.4.0-1 [110 kB]
# Get:118 http://archive.ubuntu.com/ubuntu jammy/main amd64 libiec61883-0 amd64 1.2.0-4build3 [25.9 kB]
# Get:119 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjack-jackd2-0 amd64 1.9.20~dfsg-1 [293 kB]
# Get:120 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal-data all 1:1.19.1-2build3 [164 kB]
# Get:121 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsndio7.0 amd64 1.8.1-1.1 [29.3 kB]
# Get:122 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenal1 amd64 1:1.19.1-2build3 [535 kB]
# Get:123 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-client0 amd64 1.20.0-1ubuntu0.1 [25.9 kB]
# Get:124 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdecor-0-0 amd64 0.1.0-3build1 [15.1 kB]
# Get:125 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-server0 amd64 1.20.0-1ubuntu0.1 [34.3 kB]
# Get:126 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgbm1 amd64 23.2.1-1ubuntu3.1~22.04.2 [33.5 kB]
# Get:127 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-cursor0 amd64 1.20.0-1ubuntu0.1 [10.7 kB]
# Get:128 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libwayland-egl1 amd64 1.20.0-1ubuntu0.1 [5,582 B]
# Get:129 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcursor1 amd64 1:1.2.0-2build4 [20.9 kB]
# Get:130 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxi6 amd64 2:1.8-1build1 [32.6 kB]
# Get:131 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxinerama1 amd64 2:1.1.4-3 [7,382 B]
# Get:132 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbcommon0 amd64 1.4.0-1 [125 kB]
# Get:133 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxrandr2 amd64 2:1.5.2-1build1 [20.4 kB]
# Get:134 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxss1 amd64 1:1.2.3-1build2 [8,476 B]
# Get:135 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libsdl2-2.0-0 amd64 2.0.20+dfsg-2ubuntu1.22.04.1 [582 kB]
# Get:136 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcb-shape0 amd64 1.14-3ubuntu3 [6,158 B]
# Get:137 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxv1 amd64 2:1.0.11-1build2 [11.2 kB]
# Get:138 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libavdevice58 amd64 7:4.4.2-0ubuntu0.22.04.1 [87.5 kB]
# Get:139 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 ffmpeg amd64 7:4.4.2-0ubuntu0.22.04.1 [1,696 kB]
# Get:140 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Get:141 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-liberation all 1:1.07.4-11 [822 kB]
# Get:142 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 fonts-noto-color-emoji all 2.042-0ubuntu0.22.04.1 [9,944 kB]
# Get:143 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-tlwg-loma-otf all 1:0.7.3-1 [107 kB]
# Get:144 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-unifont all 1:14.0.01-1 [3,551 kB]
# Get:145 http://archive.ubuntu.com/ubuntu jammy/universe amd64 fonts-wqy-zenhei all 0.9.45-8 [7,472 kB]
# Get:146 http://archive.ubuntu.com/ubuntu jammy/main amd64 libproxy1v5 amd64 0.4.17-2 [51.9 kB]
# Get:147 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-common all 2.72.0-1 [3,718 B]
# Get:148 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking-services amd64 2.72.0-1 [9,982 B]
# Get:149 http://archive.ubuntu.com/ubuntu jammy/main amd64 session-migration amd64 0.3.6 [9,774 B]
# Get:150 http://archive.ubuntu.com/ubuntu jammy/main amd64 gsettings-desktop-schemas all 42.0-1ubuntu1 [31.1 kB]
# Get:151 http://archive.ubuntu.com/ubuntu jammy/main amd64 glib-networking amd64 2.72.0-1 [69.8 kB]
# Get:152 http://archive.ubuntu.com/ubuntu jammy/main amd64 liborc-0.4-0 amd64 1:0.4.32-2 [228 kB]
# Get:153 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-base1.0-0 amd64 1.20.1-1ubuntu0.1 [848 kB]
# Get:154 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-libav amd64 1.20.3-0ubuntu1 [103 kB]
# Get:155 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcdparanoia0 amd64 3.10.2+debian-14build2 [49.3 kB]
# Get:156 http://archive.ubuntu.com/ubuntu jammy/main amd64 libvisual-0.4-0 amd64 0.4.0-17build2 [108 kB]
# Get:157 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-base amd64 1.20.1-1ubuntu0.1 [712 kB]
# Get:158 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaa1 amd64 1.4p5-50build1 [51.9 kB]
# Get:159 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdv4 amd64 1.0.0-14build1 [61.9 kB]
# Get:160 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-plugins-good1.0-0 amd64 1.20.3-0ubuntu1.1 [30.0 kB]
# Get:161 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgudev-1.0-0 amd64 1:237-2build1 [16.3 kB]
# Get:162 http://archive.ubuntu.com/ubuntu jammy/main amd64 libshout3 amd64 2.4.5-1build3 [54.5 kB]
# Get:163 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5-vanilla amd64 1.11.1+dfsg.1-3ubuntu3 [304 kB]
# Get:164 http://archive.ubuntu.com/ubuntu jammy/main amd64 libtag1v5 amd64 1.11.1+dfsg.1-3ubuntu3 [11.5 kB]
# Get:165 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4lconvert0 amd64 1.22.1-2build1 [82.4 kB]
# Get:166 http://archive.ubuntu.com/ubuntu jammy/main amd64 libv4l-0 amd64 1.22.1-2build1 [44.9 kB]
# Get:167 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwavpack1 amd64 5.4.0-1build2 [83.7 kB]
# Get:168 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxdamage1 amd64 1:1.1.5-2build2 [7,154 B]
# Get:169 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsoup2.4-common all 2.74.2-3 [4,008 B]
# Get:170 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsoup2.4-1 amd64 2.74.2-3 [287 kB]
# Get:171 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 gstreamer1.0-plugins-good amd64 1.20.3-0ubuntu1.1 [2,008 kB]
# Get:172 http://archive.ubuntu.com/ubuntu jammy/main amd64 hunspell-en-us all 1:2020.12.07-2 [280 kB]
# Get:173 http://archive.ubuntu.com/ubuntu jammy/main amd64 libaspell15 amd64 0.60.8-4build1 [325 kB]
# Get:174 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-data all 2.36.0-3build1 [2,824 B]
# Get:175 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk1.0-0 amd64 2.36.0-3build1 [51.9 kB]
# Get:176 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatspi2.0-0 amd64 2.44.0-3 [80.9 kB]
# Get:177 http://archive.ubuntu.com/ubuntu jammy/main amd64 libatk-bridge2.0-0 amd64 2.38.0-3 [66.6 kB]
# Get:178 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-common-data amd64 0.8-5ubuntu5.2 [23.8 kB]
# Get:179 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-common3 amd64 0.8-5ubuntu5.2 [23.9 kB]
# Get:180 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libavahi-client3 amd64 0.8-5ubuntu5.2 [28.0 kB]
# Get:181 http://archive.ubuntu.com/ubuntu jammy/main amd64 libcolord2 amd64 1.4.6-1 [155 kB]
# Get:182 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libcups2 amd64 2.4.1op1-1ubuntu4.8 [264 kB]
# Get:183 http://archive.ubuntu.com/ubuntu jammy/main amd64 libdbus-glib-1-2 amd64 0.112-2build1 [65.4 kB]
# Get:184 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdread8 amd64 6.1.2-1 [55.7 kB]
# Get:185 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdvdnav4 amd64 6.1.1-1 [39.3 kB]
# Get:186 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libegl-mesa0 amd64 23.2.1-1ubuntu3.1~22.04.2 [118 kB]
# Get:187 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhunspell-1.7-0 amd64 1.7.0-4build1 [175 kB]
# Get:188 http://archive.ubuntu.com/ubuntu jammy/main amd64 libenchant-2-2 amd64 2.3.2-1ubuntu2 [50.9 kB]
# Get:189 http://archive.ubuntu.com/ubuntu jammy/main amd64 libepoxy0 amd64 1.5.10-1 [237 kB]
# Get:190 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfaad2 amd64 2.10.0-2 [197 kB]
# Get:191 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libffi7 amd64 3.3-5ubuntu1 [19.9 kB]
# Get:192 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libinstpatch-1.0-2 amd64 1.1.6-1 [240 kB]
# Get:193 http://archive.ubuntu.com/ubuntu jammy/universe amd64 timgm6mb-soundfont all 1.3-5 [5,427 kB]
# Get:194 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfluidsynth3 amd64 2.2.5-1 [246 kB]
# Get:195 http://archive.ubuntu.com/ubuntu jammy/main amd64 libfontenc1 amd64 1:1.1.4-1build3 [14.7 kB]
# Get:196 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libfreeaptx0 amd64 0.1.1-1 [12.9 kB]
# Get:197 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgssdp-1.2-0 amd64 1.4.0.1-2build1 [48.9 kB]
# Get:198 http://archive.ubuntu.com/ubuntu jammy/main amd64 libegl1 amd64 1.4.0-1 [28.6 kB]
# Get:199 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgstreamer-gl1.0-0 amd64 1.20.1-1ubuntu0.1 [204 kB]
# Get:200 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxcomposite1 amd64 1:0.4.5-1build2 [7,192 B]
# Get:201 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-common all 3.24.33-1ubuntu2 [239 kB]
# Get:202 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libgtk-3-0 amd64 3.24.33-1ubuntu2 [3,053 kB]
# Get:203 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgupnp-1.2-1 amd64 1.4.3-1 [93.3 kB]
# Get:204 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libgupnp-igd-1.0-4 amd64 1.2.0-1build1 [16.8 kB]
# Get:205 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libharfbuzz-icu0 amd64 2.7.4-1ubuntu3.1 [5,886 B]
# Get:206 http://archive.ubuntu.com/ubuntu jammy/main amd64 libhyphen0 amd64 2.8.8-7build2 [28.2 kB]
# Get:207 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-common all 1.6.6-1build1 [4,432 B]
# Get:208 http://archive.ubuntu.com/ubuntu jammy/main amd64 libjson-glib-1.0-0 amd64 1.6.6-1build1 [69.9 kB]
# Get:209 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libkate1 amd64 0.4.1-11build1 [39.4 kB]
# Get:210 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libldacbt-enc2 amd64 2.0.2.3+git20200429+ed310a0-4 [24.6 kB]
# Get:211 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libltc11 amd64 1.3.1-1 [12.3 kB]
# Get:212 http://archive.ubuntu.com/ubuntu jammy/main amd64 libevdev2 amd64 1.12.1+dfsg-1 [39.5 kB]
# Get:213 http://archive.ubuntu.com/ubuntu jammy/main amd64 libmanette-0.2-0 amd64 0.2.6-3build1 [30.4 kB]
# Get:214 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmjpegutils-2.1-0 amd64 1:2.1.0+debian-6build1 [24.1 kB]
# Get:215 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmodplug1 amd64 1:0.8.9.0-3 [153 kB]
# Get:216 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpcdec6 amd64 2:0.1~r495-2 [32.4 kB]
# Get:217 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmpeg2encpp-2.1-0 amd64 1:2.1.0+debian-6build1 [69.4 kB]
# Get:218 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libmplex2-2.1-0 amd64 1:2.1.0+debian-6build1 [44.4 kB]
# Get:219 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libnice10 amd64 0.1.18-2 [156 kB]
# Get:220 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnotify4 amd64 0.7.9-3ubuntu5.22.04.1 [20.3 kB]
# Get:221 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnspr4 amd64 2:4.35-0ubuntu0.22.04.1 [119 kB]
# Get:222 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libnss3 amd64 2:3.98-0ubuntu0.22.04.1 [1,346 kB]
# Get:223 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenh264-6 amd64 2.2.0+dfsg-2 [407 kB]
# Get:224 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libopenni2-0 amd64 2.2.0.33+dfsg-15 [389 kB]
# Get:225 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libqrencode4 amd64 4.1.1-1 [24.0 kB]
# Get:226 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-common all 0.20.5-2 [4,278 B]
# Get:227 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsecret-1-0 amd64 0.20.5-2 [124 kB]
# Get:228 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsoundtouch1 amd64 2.3.1+ds1-1 [38.3 kB]
# Get:229 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-common all 3.0.7-0ubuntu1 [62.1 kB]
# Get:230 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libsoup-3.0-0 amd64 3.0.7-0ubuntu1 [278 kB]
# Get:231 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libspandsp2 amd64 0.0.6+dfsg-2 [272 kB]
# Get:232 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libsrtp2-1 amd64 2.4.2-2 [40.7 kB]
# Get:233 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwebrtc-audio-processing1 amd64 0.3.1-0ubuntu5 [291 kB]
# Get:234 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libwildmidi2 amd64 0.4.3-1 [59.9 kB]
# Get:235 http://archive.ubuntu.com/ubuntu jammy/main amd64 libwoff1 amd64 1.0.2-1build4 [45.2 kB]
# Get:236 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxmu6 amd64 2:1.1.3-3 [49.6 kB]
# Get:237 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 libxpm4 amd64 1:3.5.12-1ubuntu0.22.04.2 [36.7 kB]
# Get:238 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxaw7 amd64 2:1.0.14-1 [191 kB]
# Get:239 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxfont2 amd64 1:2.0.5-1build1 [94.5 kB]
# Get:240 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxkbfile1 amd64 1:1.1.0-1build3 [71.8 kB]
# Get:241 http://archive.ubuntu.com/ubuntu jammy/main amd64 libxtst6 amd64 2:1.2.3-1build4 [13.4 kB]
# Get:242 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzbar0 amd64 0.23.92-4build2 [121 kB]
# Get:243 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libzxingcore1 amd64 1.2.0-1 [619 kB]
# Get:244 http://archive.ubuntu.com/ubuntu jammy/main amd64 x11-xkb-utils amd64 7.7+5build4 [172 kB]
# Get:245 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-encodings all 1:1.0.5-0ubuntu2 [578 kB]
# Get:246 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-utils amd64 1:7.7+6build2 [94.6 kB]
# Get:247 http://archive.ubuntu.com/ubuntu jammy/universe amd64 xfonts-cyrillic all 1:1.0.5 [386 kB]
# Get:248 http://archive.ubuntu.com/ubuntu jammy/main amd64 xfonts-scalable all 1:1.0.3-1.2ubuntu1 [306 kB]
# Get:249 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 xserver-common all 2:21.1.4-2ubuntu1.7~22.04.10 [28.5 kB]
# Get:250 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 xvfb amd64 2:21.1.4-2ubuntu1.7~22.04.10 [863 kB]
# Get:251 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libdca0 amd64 0.0.7-2 [88.2 kB]
# Get:252 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 libgstreamer-plugins-bad1.0-0 amd64 1.20.3-0ubuntu1.1 [489 kB]
# Get:253 http://archive.ubuntu.com/ubuntu jammy/main amd64 libsbc1 amd64 1.5-3build2 [34.4 kB]
# Get:254 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-aacenc0 amd64 0.1.3-2 [69.4 kB]
# Get:255 http://archive.ubuntu.com/ubuntu jammy/universe amd64 libvo-amrwbenc0 amd64 0.1.3-2 [68.2 kB]
# Get:256 http://archive.ubuntu.com/ubuntu jammy-updates/universe amd64 gstreamer1.0-plugins-bad amd64 1.20.3-0ubuntu1.1 [2,602 kB]
# Get:257 http://archive.ubuntu.com/ubuntu jammy/main amd64 libgles2 amd64 1.4.0-1 [18.0 kB]
# Get:258 http://archive.ubuntu.com/ubuntu jammy/main amd64 libopengl0 amd64 1.4.0-1 [36.5 kB]
# Fetched 151 MB in 7s (21.8 MB/s)
# debconf: delaying package configuration, since apt-utils is not installed
# Selecting previously unselected package fonts-ipafont-gothic.
# (Reading database ... 35599 files and directories currently installed.)
# Preparing to unpack .../000-fonts-ipafont-gothic_00303-21ubuntu1_all.deb ...
# Unpacking fonts-ipafont-gothic (00303-21ubuntu1) ...
# Selecting previously unselected package libslang2:amd64.
# Preparing to unpack .../001-libslang2_2.3.2-5build4_amd64.deb ...
# Unpacking libslang2:amd64 (2.3.2-5build4) ...
# Selecting previously unselected package libtext-iconv-perl.
# Preparing to unpack .../002-libtext-iconv-perl_1.7-7build3_amd64.deb ...
# Unpacking libtext-iconv-perl (1.7-7build3) ...
# Selecting previously unselected package xkb-data.
# Preparing to unpack .../003-xkb-data_2.33-1_all.deb ...
# Unpacking xkb-data (2.33-1) ...
# Selecting previously unselected package libdrm-common.
# Preparing to unpack .../004-libdrm-common_2.4.113-2~ubuntu0.22.04.1_all.deb ...
# Unpacking libdrm-common (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libdrm2:amd64.
# Preparing to unpack .../005-libdrm2_2.4.113-2~ubuntu0.22.04.1_amd64.deb ...
# Unpacking libdrm2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Selecting previously unselected package libusb-1.0-0:amd64.
# Preparing to unpack .../006-libusb-1.0-0_2%3a1.0.25-1ubuntu2_amd64.deb ...
# Unpacking libusb-1.0-0:amd64 (2:1.0.25-1ubuntu2) ...
# Selecting previously unselected package libxmuu1:amd64.
# Preparing to unpack .../007-libxmuu1_2%3a1.1.3-3_amd64.deb ...
# Unpacking libxmuu1:amd64 (2:1.1.3-3) ...
# Selecting previously unselected package xauth.
# Preparing to unpack .../008-xauth_1%3a1.1-1build2_amd64.deb ...
# Unpacking xauth (1:1.1-1build2) ...
# Selecting previously unselected package gtk-update-icon-cache.
# Preparing to unpack .../009-gtk-update-icon-cache_3.24.33-1ubuntu2_amd64.deb ...
# Unpacking gtk-update-icon-cache (3.24.33-1ubuntu2) ...
# Selecting previously unselected package humanity-icon-theme.
# Preparing to unpack .../010-humanity-icon-theme_0.6.16_all.deb ...
# Unpacking humanity-icon-theme (0.6.16) ...
# Selecting previously unselected package ubuntu-mono.
# Preparing to unpack .../011-ubuntu-mono_20.10-0ubuntu2_all.deb ...
# Unpacking ubuntu-mono (20.10-0ubuntu2) ...
# Selecting previously unselected package adwaita-icon-theme.
# Preparing to unpack .../012-adwaita-icon-theme_41.0-1ubuntu1_all.deb ...
# Unpacking adwaita-icon-theme (41.0-1ubuntu1) ...
# Selecting previously unselected package dbus-user-session.
# Preparing to unpack .../013-dbus-user-session_1.12.20-2ubuntu4.1_amd64.deb ...
# Unpacking dbus-user-session (1.12.20-2ubuntu4.1) ...
# Selecting previously unselected package libdconf1:amd64.
# Preparing to unpack .../014-libdconf1_0.40.0-3_amd64.deb ...
# Unpacking libdconf1:amd64 (0.40.0-3) ...
# Selecting previously unselected package dconf-service.
# Preparing to unpack .../015-dconf-service_0.40.0-3_amd64.deb ...
# Unpacking dconf-service (0.40.0-3) ...
# Selecting previously unselected package dconf-gsettings-backend:amd64.
# Preparing to unpack .../016-dconf-gsettings-backend_0.40.0-3_amd64.deb ...
# Unpacking dconf-gsettings-backend:amd64 (0.40.0-3) ...
# Selecting previously unselected package dictionaries-common.
# Preparing to unpack .../017-dictionaries-common_1.28.14_all.deb ...
# Adding 'diversion of /usr/share/dict/words to /usr/share/dict/words.pre-dictionaries-common by dictionaries-common'
# Unpacking dictionaries-common (1.28.14) ...
# Selecting previously unselected package libva2:amd64.
# Preparing to unpack .../018-libva2_2.14.0-1_amd64.deb ...
# Unpacking libva2:amd64 (2.14.0-1) ...
# Selecting previously unselected package libmfx1:amd64.
# Preparing to unpack .../019-libmfx1_22.3.0-1_amd64.deb ...
# Unpacking libmfx1:amd64 (22.3.0-1) ...
# Selecting previously unselected package libva-drm2:amd64.
# Preparing to unpack .../020-libva-drm2_2.14.0-1_amd64.deb ...
# Unpacking libva-drm2:amd64 (2.14.0-1) ...
# Selecting previously unselected package libxfixes3:amd64.
# Preparing to unpack .../021-libxfixes3_1%3a6.0.0-1_amd64.deb ...
# Unpacking libxfixes3:amd64 (1:6.0.0-1) ...
# Selecting previously unselected package libva-x11-2:amd64.
# Preparing to unpack .../022-libva-x11-2_2.14.0-1_amd64.deb ...
# Unpacking libva-x11-2:amd64 (2.14.0-1) ...
# Selecting previously unselected package libvdpau1:amd64.
# Preparing to unpack .../023-libvdpau1_1.4-3build2_amd64.deb ...
# Unpacking libvdpau1:amd64 (1.4-3build2) ...
# Selecting previously unselected package ocl-icd-libopencl1:amd64.
# Preparing to unpack .../024-ocl-icd-libopencl1_2.2.14-3_amd64.deb ...
# Unpacking ocl-icd-libopencl1:amd64 (2.2.14-3) ...
# Selecting previously unselected package libavutil56:amd64.
# Preparing to unpack .../025-libavutil56_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libavutil56:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libcodec2-1.0:amd64.
# Preparing to unpack .../026-libcodec2-1.0_1.0.1-3_amd64.deb ...
# Unpacking libcodec2-1.0:amd64 (1.0.1-3) ...
# Selecting previously unselected package libgsm1:amd64.
# Preparing to unpack .../027-libgsm1_1.0.19-1_amd64.deb ...
# Unpacking libgsm1:amd64 (1.0.19-1) ...
# Selecting previously unselected package libmp3lame0:amd64.
# Preparing to unpack .../028-libmp3lame0_3.100-3build2_amd64.deb ...
# Unpacking libmp3lame0:amd64 (3.100-3build2) ...
# Selecting previously unselected package libopus0:amd64.
# Preparing to unpack .../029-libopus0_1.3.1-0.1build2_amd64.deb ...
# Unpacking libopus0:amd64 (1.3.1-0.1build2) ...
# Selecting previously unselected package libshine3:amd64.
# Preparing to unpack .../030-libshine3_3.1.1-2_amd64.deb ...
# Unpacking libshine3:amd64 (3.1.1-2) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../031-libsnappy1v5_1.1.8-1build3_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.8-1build3) ...
# Selecting previously unselected package libspeex1:amd64.
# Preparing to unpack .../032-libspeex1_1.2~rc1.2-1.1ubuntu3_amd64.deb ...
# Unpacking libspeex1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Selecting previously unselected package libsoxr0:amd64.
# Preparing to unpack .../033-libsoxr0_0.1.3-4build2_amd64.deb ...
# Unpacking libsoxr0:amd64 (0.1.3-4build2) ...
# Selecting previously unselected package libswresample3:amd64.
# Preparing to unpack .../034-libswresample3_7%3a4.4.2-0ubuntu0.22.04.1_amd64.deb ...
# Unpacking libswresample3:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Selecting previously unselected package libogg0:amd64.
# Preparing to unpack .../035-libogg0_1.3.5-0ubuntu3_amd64.deb ...
# Unpacking libogg0:amd64 (1.3.5-0ubuntu3) ...
# Selecting previously unselected package libtheora0:amd64.
# Preparing to unpack .../036-libtheora0_1.1.1+dfsg.1-15ubuntu4_amd64.deb ...
# Unpacking libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu4) ...
# Selecting previously unselected package libtwolame0:amd64.
# Preparing to unpack .../037-libtwolame0_0.4.0-2build2_amd64.deb ...
# Unpacking libtwolame0:amd64 (0.4.0-2build2) ...
# Selecting previously unselected package libvorbis0a:amd64.
# Preparing to unpack .../038-libvorbis0a_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbis0a:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libvorbisenc2:amd64.
# Preparing to unpack .../039-libvorbisenc2_1.3.7-1build2_amd64.deb ...
# Unpacking libvorbisenc2:amd64 (1.3.7-1build2) ...
# Selecting previously unselected package libvpx7:amd64.
# Preparing to unpack .../040-libvpx7_1.11.0-2ubuntu2.2_amd64.deb ...
# Unpacking libvpx7:amd64 (1.11.0-2ubuntu2.2) ...
# Selecting previously unselected package libx264-163:amd64.
# Preparing to unpack .../041-libx264-163_2%3a0.163.3060+git5db6aa6-2build1_amd64.deb ...
# Unpacking libx264-163:amd64 (2:0.163.3060+git5db6aa6-2build1) ...
# Selecting previously unselected package libxvidcore4:amd64.
# Preparing to unpack .../042-libxvidcore4_2%3a1.3.7-1_amd64.deb ...
# Unpacking libxvidcore4:amd64 (2:1.3.7-1) ...
# Selecting previously unselected package libzvbi-common.
# Preparing to unpack .../043-libzvbi-common_0.2.35-19_all.deb ...
# ...
# Unpacking libvo-aacenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package libvo-amrwbenc0:amd64.
# Preparing to unpack .../254-libvo-amrwbenc0_0.1.3-2_amd64.deb ...
# Unpacking libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Selecting previously unselected package gstreamer1.0-plugins-bad:amd64.
# Preparing to unpack .../255-gstreamer1.0-plugins-bad_1.20.3-0ubuntu1.1_amd64.deb ...
# Unpacking gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Selecting previously unselected package libgles2:amd64.
# Preparing to unpack .../256-libgles2_1.4.0-1_amd64.deb ...
# Unpacking libgles2:amd64 (1.4.0-1) ...
# Selecting previously unselected package libopengl0:amd64.
# Preparing to unpack .../257-libopengl0_1.4.0-1_amd64.deb ...
# Unpacking libopengl0:amd64 (1.4.0-1) ...
# Setting up libgme0:amd64 (0.6.3-2) ...
# Setting up libssh-gcrypt-4:amd64 (0.9.6-2ubuntu0.22.04.3) ...
# Setting up libtext-iconv-perl (1.7-7build3) ...
# Setting up libsrt1.4-gnutls:amd64 (1.4.4-4) ...
# Setting up libxcb-dri3-0:amd64 (1.14-3ubuntu3) ...
# Setting up libfreeaptx0:amd64 (0.1.1-1) ...
# Setting up libudfread0:amd64 (1.1.2-1) ...
# Setting up libmodplug1:amd64 (1:0.8.9.0-3) ...
# Setting up libcdparanoia0:amd64 (3.10.2+debian-14build2) ...
# Setting up libwayland-server0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up gtk-update-icon-cache (3.24.33-1ubuntu2) ...
# Setting up libx11-xcb1:amd64 (2:1.7.5-1ubuntu0.3) ...
# Setting up libvo-amrwbenc0:amd64 (0.1.3-2) ...
# Setting up libpciaccess0:amd64 (0.16-3) ...
# Setting up session-migration (0.3.6) ...
# Created symlink /etc/systemd/user/graphical-session-pre.target.wants/session-migration.service → /usr/lib/systemd/user/session-migration.service.
# Setting up librabbitmq4:amd64 (0.10.0-1ubuntu2) ...
# Setting up libraw1394-11:amd64 (2.1.2-2build2) ...
# Setting up libsbc1:amd64 (1.5-3build2) ...
# Setting up libproxy1v5:amd64 (0.4.17-2) ...
# Setting up libxmu6:amd64 (2:1.1.3-3) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libkate1:amd64 (0.4.1-11build1) ...
# Setting up libharfbuzz-icu0:amd64 (2.7.4-1ubuntu3.1) ...
# Setting up libcodec2-1.0:amd64 (1.0.1-3) ...
# Setting up libxdamage1:amd64 (1:1.1.5-2build2) ...
# Setting up libmpg123-0:amd64 (1.29.3-1build1) ...
# Setting up libxcb-xfixes0:amd64 (1.14-3ubuntu3) ...
# Setting up libogg0:amd64 (1.3.5-0ubuntu3) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1.1ubuntu3) ...
# Setting up libshine3:amd64 (3.1.1-2) ...
# Setting up libxpm4:amd64 (1:3.5.12-1ubuntu0.22.04.2) ...
# Setting up libxi6:amd64 (2:1.8-1build1) ...
# Setting up libtwolame0:amd64 (0.4.0-2build2) ...
# Setting up libwoff1:amd64 (1.0.2-1build4) ...
# Setting up libqrencode4:amd64 (4.1.1-1) ...
# Setting up libhyphen0:amd64 (2.8.8-7build2) ...
# Setting up dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Install emacsen-common for emacs
# emacsen-common: Handling install of emacsen flavor emacs
# Install dictionaries-common for emacs
# install/dictionaries-common: Byte-compiling for emacsen flavour emacs
# Setting up fonts-noto-color-emoji (2.042-0ubuntu0.22.04.1) ...
# Setting up libgsm1:amd64 (1.0.19-1) ...
# Setting up libvisual-0.4-0:amd64 (0.4.0-17build2) ...
# Setting up libsoxr0:amd64 (0.1.3-4build2) ...
# Setting up libaspell15:amd64 (0.60.8-4build1) ...
# Setting up libglvnd0:amd64 (1.4.0-1) ...
# Setting up libpgm-5.3-0:amd64 (5.3.128~dfsg-2) ...
# Setting up libxtst6:amd64 (2:1.2.3-1build4) ...
# Setting up libxcb-glx0:amd64 (1.14-3ubuntu3) ...
# Setting up libffi7:amd64 (3.3-5ubuntu1) ...
# Setting up libnorm1:amd64 (1.5.9+dfsg-2) ...
# Setting up libmysofa1:amd64 (1.2.1~dfsg0-1) ...
# Setting up libxcb-shape0:amd64 (1.14-3ubuntu3) ...
# Setting up libsensors-config (1:3.6.0-7ubuntu1) ...
# Setting up libldacbt-enc2:amd64 (2.0.2.3+git20200429+ed310a0-4) ...
# Setting up fonts-wqy-zenhei (0.9.45-8) ...
# Setting up libwebrtc-audio-processing1:amd64 (0.3.1-0ubuntu5) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Setting up xkb-data (2.33-1) ...
# Setting up libxaw7:amd64 (2:1.0.14-1) ...
# Setting up libatspi2.0-0:amd64 (2.44.0-3) ...
# Setting up libsoup-3.0-common (3.0.7-0ubuntu1) ...
# Setting up libcdio19:amd64 (2.1.0-3build1) ...
# Setting up libxvidcore4:amd64 (2:1.3.7-1) ...
# Setting up libmpcdec6:amd64 (2:0.1~r495-2) ...
# Setting up libcolord2:amd64 (1.4.6-1) ...
# Setting up libopengl0:amd64 (1.4.0-1) ...
# Setting up libspandsp2:amd64 (0.0.6+dfsg-2) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1build3) ...
# Setting up libflac8:amd64 (1.3.3-2ubuntu0.2) ...
# Setting up libsnappy1v5:amd64 (1.1.8-1build3) ...
# Setting up libvo-aacenc0:amd64 (0.1.3-2) ...
# Setting up libxcb-present0:amd64 (1.14-3ubuntu3) ...
# Setting up libdconf1:amd64 (0.40.0-3) ...
# Setting up dbus-user-session (1.12.20-2ubuntu4.1) ...
# Setting up libfontenc1:amd64 (1:1.1.4-1build3) ...
# Setting up libblas3:amd64 (3.10.0-2ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/blas/libblas.so.3 to provide /usr/lib/x86_64-linux-gnu/libblas.so.3 (libblas.so.3-x86_64-linux-gnu) in auto mode
# Setting up libsoundtouch1:amd64 (2.3.1+ds1-1) ...
# Setting up libgles2:amd64 (1.4.0-1) ...
# Setting up fonts-tlwg-loma-otf (1:0.7.3-1) ...
# Setting up libass9:amd64 (1:0.15.2-1) ...
# Setting up libdvdread8:amd64 (6.1.2-1) ...
# Setting up libslang2:amd64 (2.3.2-5build4) ...
# Setting up libva2:amd64 (2.14.0-1) ...
# Setting up libepoxy0:amd64 (1.5.10-1) ...
# Setting up libnspr4:amd64 (2:4.35-0ubuntu0.22.04.1) ...
# Setting up libxfixes3:amd64 (1:6.0.0-1) ...
# Setting up libxcb-sync1:amd64 (1.14-3ubuntu3) ...
# Setting up libdbus-glib-1-2:amd64 (0.112-2build1) ...
# Setting up libnotify4:amd64 (0.7.9-3ubuntu5.22.04.1) ...
# Setting up libavahi-common-data:amd64 (0.8-5ubuntu5.2) ...
# Setting up libx264-163:amd64 (2:0.163.3060+git5db6aa6-2build1) ...
# Setting up xfonts-encodings (1:1.0.5-0ubuntu2) ...
# Setting up libopus0:amd64 (1.3.1-0.1build2) ...
# Setting up libfaad2:amd64 (2.10.0-2) ...
# Setting up libxinerama1:amd64 (2:1.1.4-3) ...
# Setting up libxv1:amd64 (2:1.0.11-1build2) ...
# Setting up libvorbis0a:amd64 (1.3.7-1build2) ...
# Setting up libxrandr2:amd64 (2:1.5.2-1build1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.32-2) ...
# Setting up libsensors5:amd64 (1:3.6.0-7ubuntu1) ...
# Setting up libglapi-mesa:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libgfortran5:amd64 (12.3.0-1ubuntu1~22.04) ...
# Setting up libltc11:amd64 (1.3.1-1) ...
# Setting up libsoup2.4-common (2.74.2-3) ...
# Setting up libsndio7.0:amd64 (1.8.1-1.1) ...
# Setting up libxcb-dri2-0:amd64 (1.14-3ubuntu3) ...
# Setting up libatk1.0-data (2.36.0-3build1) ...
# Setting up libvidstab1.1:amd64 (1.1.0-2) ...
# Setting up libtag1v5:amd64 (1.11.1+dfsg.1-3ubuntu3) ...
# Setting up libflite1:amd64 (2.2-3) ...
# Setting up libdv4:amd64 (1.0.0-14build1) ...
# Setting up fonts-ipafont-gothic (00303-21ubuntu1) ...
# update-alternatives: using /usr/share/fonts/opentype/ipafont-gothic/ipag.ttf to provide /usr/share/fonts/truetype/fonts-japanese-gothic.ttf (fonts-japanese-gothic.ttf) in auto mode
# Setting up ocl-icd-libopencl1:amd64 (2.2.14-3) ...
# Setting up libasyncns0:amd64 (0.8-6build2) ...
# Setting up libwildmidi2:amd64 (0.4.3-1) ...
# Setting up libxshmfence1:amd64 (1.3-1build4) ...
# Setting up libopenh264-6:amd64 (2.2.0+dfsg-2) ...
# Setting up libvdpau1:amd64 (1.4-3build2) ...
# Setting up libwavpack1:amd64 (5.4.0-1build2) ...
# Setting up libbs2b0:amd64 (3.1.0+dfsg-2.2build1) ...
# Setting up libxcb-randr0:amd64 (1.14-3ubuntu3) ...
# Setting up libzxingcore1:amd64 (1.2.0-1) ...
# Setting up libtheora0:amd64 (1.1.1+dfsg.1-15ubuntu4) ...
# Setting up libv4lconvert0:amd64 (1.22.1-2build1) ...
# Setting up fonts-liberation (1:1.07.4-11) ...
# Setting up hunspell-en-us (1:2020.12.07-2) ...
# Setting up libdca0:amd64 (0.0.7-2) ...
# Setting up libzimg2:amd64 (3.0.3+ds1-1) ...
# Setting up libopenal-data (1:1.19.1-2build3) ...
# Setting up libjson-glib-1.0-common (1.6.6-1build1) ...
# Setting up libvpx7:amd64 (1.11.0-2ubuntu2.2) ...
# Setting up libatk1.0-0:amd64 (2.36.0-3build1) ...
# Setting up libwayland-egl1:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libxss1:amd64 (1:1.2.3-1build2) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.25-1ubuntu2) ...
# Setting up libxkbfile1:amd64 (1:1.1.0-1build3) ...
# Setting up libhunspell-1.7-0:amd64 (1.7.0-4build1) ...
# Setting up glib-networking-common (2.72.0-1) ...
# Setting up libmfx1:amd64 (22.3.0-1) ...
# Setting up libsamplerate0:amd64 (0.2.2-1build1) ...
# Setting up timgm6mb-soundfont (1.3-5) ...
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf2/default-GM.sf2 (default-GM.sf2) in auto mode
# update-alternatives: using /usr/share/sounds/sf2/TimGM6mb.sf2 to provide /usr/share/sounds/sf3/default-GM.sf3 (default-GM.sf3) in auto mode
# Setting up libdrm-common (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libxcomposite1:amd64 (1:0.4.5-1build2) ...
# Setting up libxfont2:amd64 (1:2.0.5-1build1) ...
# Setting up libevdev2:amd64 (1.12.1+dfsg-1) ...
# Setting up libxml2:amd64 (2.9.14+dfsg-0.1+ubuntu22.04.1+deb.sury.org+1) ...
# Setting up libmjpegutils-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libxmuu1:amd64 (2:1.1.3-3) ...
# Setting up libgudev-1.0-0:amd64 (1:237-2build1) ...
# Setting up libzvbi-common (0.2.35-19) ...
# Setting up libsecret-common (0.20.5-2) ...
# Setting up libmp3lame0:amd64 (3.100-3build2) ...
# Setting up libvorbisenc2:amd64 (1.3.7-1build2) ...
# Setting up libdvdnav4:amd64 (6.1.1-1) ...
# Setting up fonts-unifont (1:14.0.01-1) ...
# Setting up libaa1:amd64 (1.4p5-50build1) ...
# Setting up libiec61883-0:amd64 (1.2.0-4build3) ...
# Setting up libserd-0-0:amd64 (0.30.10-2) ...
# Setting up libxkbcommon0:amd64 (1.4.0-1) ...
# Setting up libwayland-client0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up libavc1394-0:amd64 (0.5.4-5build2) ...
# Setting up glib-networking-services (2.72.0-1) ...
# Setting up libzvbi0:amd64 (0.2.35-19) ...
# Setting up liblapack3:amd64 (3.10.0-2ubuntu1) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/lapack/liblapack.so.3 to provide /usr/lib/x86_64-linux-gnu/liblapack.so.3 (liblapack.so.3-x86_64-linux-gnu) in auto mode
# Setting up libopenni2-0:amd64 (2.2.0.33+dfsg-15) ...
# Setting up libzmq5:amd64 (4.3.4-2) ...
# Setting up libcaca0:amd64 (0.99.beta19-2.2ubuntu4) ...
# Setting up libenchant-2-2:amd64 (2.3.2-1ubuntu2) ...
# Setting up libcdio-cdda2:amd64 (10.2+2.0.0-1build3) ...
# Setting up x11-xkb-utils (7.7+5build4) ...
# Setting up libcdio-paranoia2:amd64 (10.2+2.0.0-1build3) ...
# Setting up libmanette-0.2-0:amd64 (0.2.6-3build1) ...
# Setting up libxcursor1:amd64 (1:1.2.0-2build4) ...
# Setting up libavahi-common3:amd64 (0.8-5ubuntu5.2) ...
# Setting up libgstreamer-plugins-base1.0-0:amd64 (1.20.1-1ubuntu0.1) ...
# Setting up dconf-service (0.40.0-3) ...
# Setting up libnss3:amd64 (2:3.98-0ubuntu0.22.04.1) ...
# Setting up libopenal1:amd64 (1:1.19.1-2build3) ...
# Setting up xfonts-utils (1:7.7+6build2) ...
# Setting up libjson-glib-1.0-0:amd64 (1.6.6-1build1) ...
# Setting up libv4l-0:amd64 (1.22.1-2build1) ...
# Setting up libatk-bridge2.0-0:amd64 (2.38.0-3) ...
# Setting up libvorbisfile3:amd64 (1.3.7-1build2) ...
# Setting up libxml2-dev:amd64 (2.9.14+dfsg-0.1+ubuntu22.04.1+deb.sury.org+1) ...
# Setting up libsecret-1-0:amd64 (0.20.5-2) ...
# Setting up libgstreamer-plugins-good1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up gstreamer1.0-plugins-base:amd64 (1.20.1-1ubuntu0.1) ...
# Setting up libdc1394-25:amd64 (2.2.6-4) ...
# Setting up libshout3:amd64 (2.4.5-1build3) ...
# Setting up libmpeg2encpp-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up librubberband2:amd64 (2.0.0-2) ...
# Setting up libjack-jackd2-0:amd64 (1.9.20~dfsg-1) ...
# Setting up libdrm2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libva-drm2:amd64 (2.14.0-1) ...
# Setting up xauth (1:1.1-1build2) ...
# Setting up libsord-0-0:amd64 (0.16.8-2) ...
# Setting up libwayland-cursor0:amd64 (1.20.0-1ubuntu0.1) ...
# Setting up xfonts-cyrillic (1:1.0.5) ...
# Setting up libsratom-0-0:amd64 (0.6.8-1) ...
# Setting up libllvm15:amd64 (1:15.0.7-0ubuntu0.22.04.3) ...
# Setting up libdecor-0-0:amd64 (0.1.0-3build1) ...
# Setting up libmplex2-2.1-0:amd64 (1:2.1.0+debian-6build1) ...
# Setting up libsndfile1:amd64 (1.0.31-2ubuntu0.1) ...
# Setting up xserver-common (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up libbluray2:amd64 (1:1.3.1-1) ...
# Setting up libva-x11-2:amd64 (2.14.0-1) ...
# Setting up liblilv-0-0:amd64 (0.24.12-2) ...
# Setting up libopenmpt0:amd64 (0.6.1-1) ...
# Setting up libinstpatch-1.0-2:amd64 (1.1.6-1) ...
# Setting up libavahi-client3:amd64 (0.8-5ubuntu5.2) ...
# Setting up xfonts-scalable (1:1.0.3-1.2ubuntu1) ...
# Setting up libdrm-amdgpu1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libdrm-nouveau2:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up dconf-gsettings-backend:amd64 (0.40.0-3) ...
# Setting up libgbm1:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libpulse0:amd64 (1:15.99.1+dfsg1-1ubuntu2.2) ...
# Setting up libzbar0:amd64 (0.23.92-4build2) ...
# Setting up libdrm-radeon1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libsrtp2-1:amd64 (2.4.2-2) ...
# Setting up libdrm-intel1:amd64 (2.4.113-2~ubuntu0.22.04.1) ...
# Setting up libgl1-mesa-dri:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libavutil56:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libgstreamer-plugins-bad1.0-0:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libegl-mesa0:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libpostproc55:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libcups2:amd64 (2.4.1op1-1ubuntu4.8) ...
# Setting up libegl1:amd64 (1.4.0-1) ...
# Setting up libswscale5:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libsdl2-2.0-0:amd64 (2.0.20+dfsg-2ubuntu1.22.04.1) ...
# Setting up libgtk-3-common (3.24.33-1ubuntu2) ...
# Setting up libfluidsynth3:amd64 (2.2.5-1) ...
# Setting up gsettings-desktop-schemas (42.0-1ubuntu1) ...
# Setting up libglx-mesa0:amd64 (23.2.1-1ubuntu3.1~22.04.2) ...
# Setting up libglx0:amd64 (1.4.0-1) ...
# Setting up libsphinxbase3:amd64 (0.8+5prealpha+1-13build1) ...
# Setting up libswresample3:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libpocketsphinx3:amd64 (0.8.0+real5prealpha+1-14ubuntu1) ...
# Setting up libgl1:amd64 (1.4.0-1) ...
# Setting up libavcodec58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up libchromaprint1:amd64 (1.5.1-2) ...
# Setting up libavformat58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up xvfb (2:21.1.4-2ubuntu1.7~22.04.10) ...
# Setting up libgstreamer-gl1.0-0:amd64 (1.20.1-1ubuntu0.1) ...
# Setting up libavfilter7:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up gstreamer1.0-libav:amd64 (1.20.3-0ubuntu1) ...
# Setting up libavdevice58:amd64 (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up ffmpeg (7:4.4.2-0ubuntu0.22.04.1) ...
# Setting up adwaita-icon-theme (41.0-1ubuntu1) ...
# update-alternatives: using /usr/share/icons/Adwaita/cursor.theme to provide /usr/share/icons/default/index.theme (x-cursor-theme) in auto mode
# Setting up humanity-icon-theme (0.6.16) ...
# Setting up ubuntu-mono (20.10-0ubuntu2) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...
# Processing triggers for libglib2.0-0:amd64 (2.72.4-0ubuntu2.2) ...
# Setting up libgtk-3-0:amd64 (3.24.33-1ubuntu2) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.6) ...
# Setting up glib-networking:amd64 (2.72.0-1) ...
# Setting up libsoup2.4-1:amd64 (2.74.2-3) ...
# Setting up gstreamer1.0-plugins-good:amd64 (1.20.3-0ubuntu1.1) ...
# Setting up libsoup-3.0-0:amd64 (3.0.7-0ubuntu1) ...
# Setting up libgssdp-1.2-0:amd64 (1.4.0.1-2build1) ...
# Setting up libgupnp-1.2-1:amd64 (1.4.3-1) ...
# Setting up libgupnp-igd-1.0-4:amd64 (1.2.0-1build1) ...
# Setting up libnice10:amd64 (0.1.18-2) ...
# Setting up gstreamer1.0-plugins-bad:amd64 (1.20.3-0ubuntu1.1) ...
# Processing triggers for dictionaries-common (1.28.14) ...
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78.)
# debconf: falling back to frontend: Readline
# Processing triggers for libc-bin (2.35-0ubuntu3.6) ...

# %%
import re
import asyncio
# import playwright
# from playwright.sync_api import Page, expect
from playwright.async import Playwright, async, expect

# %%
import asyncio
from playwright.async_api import async_playwright, Playwright

async def run(playwright: Playwright):
    chromium = playwright.chromium # or "firefox" or "webkit".
    browser = await chromium.launch()
    page = await browser.new_page()
    await page.goto("https://www.dsquared2.com/us/men/ready-to-wear/coats-outerwear")
    
    
    # other actions...
    await browser.close()

async def main():
    async with async_playwright() as playwright:
        await run(playwright)
await(main())

# %%
with async_playwright() as p:
    #We define the browser, the context and the page
    browser = p.chromium.launch(headless=False)
    context = browser.new_context()
    page = browser.new_page()
    url = 'https://www.dsquared2.com/us/men/ready-to-wear/coats-outerwear'

    try:
        page.goto(url)
    except:
        pass
    
    context.close()
    browser.close()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Untitled-1.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=0'>1</a> with async_playwright() as p:
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=1'>2</a>     #We define the browser, the context and the page
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=2'>3</a>     browser = p.chromium.launch(headless=False)
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=3'>4</a>     context = browser.new_context()
#
# NameError: name 'async_playwright' is not defined

# %%
test_has_title(page)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Untitled-1.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=0'>1</a> test_has_title(page)
#
# Untitled-1.ipynb Cell 6 line 2
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=0'>1</a> def test_has_title(page):
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=1'>2</a>     page.goto("https://playwright.dev/")
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=3'>4</a>     # Expect a title "to contain" a substring.
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W5sdW50aXRsZWQ%3D?line=4'>5</a>     expect(page).to_have_title(re.compile("Playwright"))
#
# AttributeError: 'str' object has no attribute 'goto'

# %%
# page.getByText(REGEX LOAD ## MORE)
# look into locators and actions for playwright (click buttons)
# 
# 
# (maybe look at selenium vs playwright)
